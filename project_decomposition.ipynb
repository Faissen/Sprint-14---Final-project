# %% [markdown]
# # Final project - Step by step plan

# %% [markdown]
# ## Step 1 - Get the data
# - Use VSCode
# - Connect to the database
# - Import libraries
# - Import files
# - Code

# %% [markdown]
# ## Step 2 - Exploratory Data Analysis
# - Check the data with
#   - info()
#   - describe()
#   - head()
# - Solve null-values, duplicates (drop_duplicated()), change incorrect data types if needed, columns/data errors
# - Split the data with goupby()
# - Plot data to get visual perception

# %% [markdown]
# ## Step 3 - A/B Test
# - Is it possible to run A/A test prior to A/B test to
#   - Check that results are not influenced by other things
# - Define hypothesis
# - Should we use to prioritize hyposthesis (ICE, RICE)?
# - Check if the data is normally distributed (Shapiro-Wilk, Wilcoxon-Mann-Whitney)
# - Check and filter atypical values
# - Analyze test duration adequacy
# - Draw conclusions

# %% [markdown]
# ## Step 4 - SQL
# - Define the problem statement
# - Check the data diagram to get familiar with the data structure
# - Consult the database data with SQL instructions
# - Save the results
# - Draw conclusions

# %% [markdown]
# # Step 5 - Create a dashboard in Tableau
# - Define the problem statement
# - Define the layout of the dashboard
# - EDA the data
# - Define new calculations/metrics if needed
# - Create the plots
# - Create the dashboard
# - Save the work online

# %% [markdown]
# # Step 6 - Send the project
# - Attach notebook with the code (.ipynb)
# - Attach a presentation (.pdf)
# - Send the Tableau Public dashboard link (`dashboard.txt`)
